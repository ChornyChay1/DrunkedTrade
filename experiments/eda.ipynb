# %%
import pandas as pd

# %%
data = pd.read_csv("BTCUSDT_3months_20260223_213051.csv")
data["timestamp"] = pd.to_datetime(data["timestamp"], unit="s")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(80, 10))

plt.plot_date(data["timestamp"], data["open"])
plt.show()
# Out:
# C:\Users\Ilya\AppData\Local\Temp\ipykernel_9856\2931824997.py:5: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(data["timestamp"], data["open"])

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined
